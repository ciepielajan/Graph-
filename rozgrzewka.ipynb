# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_values = [1, 2, 3, 4]
y_values = [0, 0, 0, 0]
plt.plot(x_values, y_values, marker=".", markersize=10)

# %%
x_values = [1, 2, 2, 1,1.5,1]
y_values = [0, 0, 1, 1,0.5,0]
plt.plot(x_values, y_values, marker=".", markersize=20)
